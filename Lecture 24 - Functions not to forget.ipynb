# %% [markdown]
# # Functions not to forget
#
# * Not frequently used but come in handy for some tasks

# %% [markdown]
# ## Exercise 1 - clip function
#
# * Trim values at input threshold(s)

# %%
import numpy as np
import pandas as pd

df = pd.DataFrame(np.random.randint(-10, 10, size=(5, 5)), columns=list("ABCDE"))

df
# Out:
#    A  B  C   D  E
# 0 -7 -7  7  -3 -5
# 1  5 -4  2   2 -5
# 2  0 -7  8   9  8
# 3 -6  7 -3   1 -8
# 4  5 -5 -9 -10 -2

# %%
df.clip(lower=-4)
# Out:
#    A  B  C  D  E
# 0 -4 -4  7 -3 -4
# 1  5 -4  2  2 -4
# 2  0 -4  8  9  8
# 3 -4  7 -3  1 -4
# 4  5 -4 -4 -4 -2

# %%
df.clip(lower=-4, upper=4)
# Out:
#    A  B  C  D  E
# 0 -4 -4  4 -3 -4
# 1  4 -4  2  2 -4
# 2  0 -4  4  4  4
# 3 -4  4 -3  1 -4
# 4  4 -4 -4 -4 -2

# %%
df
# Out:
#    A  B  C   D  E
# 0 -7 -7  7  -3 -5
# 1  5 -4  2   2 -5
# 2  0 -7  8   9  8
# 3 -6  7 -3   1 -8
# 4  5 -5 -9 -10 -2

# %%
df.clip(lower=-4, upper=4, inplace=True)

df
# Out:
#    A  B  C  D  E
# 0 -4 -4  4 -3 -4
# 1  4 -4  2  2 -4
# 2  0 -4  4  4  4
# 3 -4  4 -3  1 -4
# 4  4 -4 -4 -4 -2

# %% [markdown]
# ## Exercise 2 - diff function
#
# * Calculates the difference of a DataFrame element compared with another element in the DataFrame (default is element in previous row).

# %%
df = pd.DataFrame(np.random.randint(0, 10, size=(5, 5)), columns=list("ABCDE"))

df
# Out:
#    A  B  C  D  E
# 0  3  7  4  2  4
# 1  5  5  7  2  7
# 2  3  4  3  9  7
# 3  7  9  7  0  2
# 4  8  4  9  0  3

# %%
df.diff()
# Out:
#      A    B    C    D    E
# 0  NaN  NaN  NaN  NaN  NaN
# 1  2.0 -2.0  3.0  0.0  3.0
# 2 -2.0 -1.0 -4.0  7.0  0.0
# 3  4.0  5.0  4.0 -9.0 -5.0
# 4  1.0 -5.0  2.0  0.0  1.0

# %%
df.diff(axis=1)
# Out:
#     A  B  C  D  E
# 0 NaN  4 -3 -2  2
# 1 NaN  0  2 -5  5
# 2 NaN  1 -1  6 -2
# 3 NaN  2 -2 -7  2
# 4 NaN -4  5 -9  3

# %% [markdown]
# ## Exercise 3 - diff function

# %%
df.diff(periods=1)
# Out:
#      A    B    C    D    E
# 0  NaN  NaN  NaN  NaN  NaN
# 1  2.0 -2.0  3.0  0.0  3.0
# 2 -2.0 -1.0 -4.0  7.0  0.0
# 3  4.0  5.0  4.0 -9.0 -5.0
# 4  1.0 -5.0  2.0  0.0  1.0

# %%
df.diff(periods=2)
# Out:
#      A    B    C    D    E
# 0  NaN  NaN  NaN  NaN  NaN
# 1  NaN  NaN  NaN  NaN  NaN
# 2  0.0 -3.0 -1.0  7.0  3.0
# 3  2.0  4.0  0.0 -2.0 -5.0
# 4  5.0  0.0  6.0 -9.0 -4.0

# %%
df.diff(periods=-1)
# Out:
#      A    B    C    D    E
# 0 -2.0  2.0 -3.0  0.0 -3.0
# 1  2.0  1.0  4.0 -7.0  0.0
# 2 -4.0 -5.0 -4.0  9.0  5.0
# 3 -1.0  5.0 -2.0  0.0 -1.0
# 4  NaN  NaN  NaN  NaN  NaN

# %%
df
# Out:
#    A  B  C  D  E
# 0  3  7  4  2  4
# 1  5  5  7  2  7
# 2  3  4  3  9  7
# 3  7  9  7  0  2
# 4  8  4  9  0  3

# %% [markdown]
# ## Exercise 4 - corr function
#
# * Compute pairwise correlation of columns, excluding NA/null values.

# %%
churn = pd.read_csv(
    
    "Data/BankChurners.csv",
    usecols=["Customer_Age", "Total_Trans_Ct", "Total_Trans_Amt", "Credit_Limit"]

)

churn.head()
# Out:
#    Customer_Age  Credit_Limit  Total_Trans_Amt  Total_Trans_Ct
# 0            45       12691.0             1144              42
# 1            49        8256.0             1291              33
# 2            51        3418.0             1887              20
# 3            40        3313.0             1171              20
# 4            40        4716.0              816              28

# %%
churn[["Customer_Age", "Credit_Limit"]].corr()
# Out:
#               Customer_Age  Credit_Limit
# Customer_Age      1.000000      0.002476
# Credit_Limit      0.002476      1.000000

# %%
churn.corr()
# Out:
#                  Customer_Age  Credit_Limit  Total_Trans_Amt  Total_Trans_Ct
# Customer_Age         1.000000      0.002476        -0.046446       -0.067097
# Credit_Limit         0.002476      1.000000         0.171730        0.075927
# Total_Trans_Amt     -0.046446      0.171730         1.000000        0.807192
# Total_Trans_Ct      -0.067097      0.075927         0.807192        1.000000

# %% [markdown]
# ## Exercise 5 - transform function

# %%
import numpy as np

df = pd.DataFrame(np.random.randint(0, 10, size=(5, 3)), columns=list("ABC"))

df
# Out:
#    A  B  C
# 0  7  7  7
# 1  7  1  9
# 2  6  2  2
# 3  2  4  3
# 4  8  8  6

# %%
np.sqrt(df)
# Out:
#           A         B         C
# 0  2.645751  2.645751  2.645751
# 1  2.645751  1.000000  3.000000
# 2  2.449490  1.414214  1.414214
# 3  1.414214  2.000000  1.732051
# 4  2.828427  2.828427  2.449490

# %%
df.transform(np.sqrt)
# Out:
#           A         B         C
# 0  2.645751  2.645751  2.645751
# 1  2.645751  1.000000  3.000000
# 2  2.449490  1.414214  1.414214
# 3  1.414214  2.000000  1.732051
# 4  2.828427  2.828427  2.449490

# %%
df.transform([np.sqrt, np.square])
# Out:
#           A                B                C
#        sqrt square      sqrt square      sqrt square
# 0  2.645751     49  2.645751     49  2.645751     49
# 1  2.645751     49  1.000000      1  3.000000     81
# 2  2.449490     36  1.414214      4  1.414214      4
# 3  1.414214      4  2.000000     16  1.732051      9
# 4  2.828427     64  2.828427     64  2.449490     36

# %% [markdown]
# ## Exercise 6 - transform function

# %%
df.transform(lambda x: np.sqrt(x) + 0.002)
# Out:
#           A         B         C
# 0  2.647751  2.647751  2.647751
# 1  2.647751  1.002000  3.002000
# 2  2.451490  1.416214  1.416214
# 3  1.416214  2.002000  1.734051
# 4  2.830427  2.830427  2.451490

# %% [markdown]
# ## Exercise 7 - get_dummies function

# %%
churn = pd.read_csv(
    
    "Data/BankChurners.csv",
    usecols=["Customer_Age", "Attrition_Flag", "Gender", "Credit_Limit"]

)

churn.head()
# Out:
#       Attrition_Flag  Customer_Age Gender  Credit_Limit
# 0  Existing Customer            45      M       12691.0
# 1  Existing Customer            49      F        8256.0
# 2  Existing Customer            51      M        3418.0
# 3  Existing Customer            40      F        3313.0
# 4  Existing Customer            40      M        4716.0

# %%
churn["Gender"].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
pd.get_dummies(churn)
# Out:
#        Customer_Age  Credit_Limit  Attrition_Flag_Attrited Customer  \
# 0                45       12691.0                             False
# 1                49        8256.0                             False
# 2                51        3418.0                             False
# 3                40        3313.0                             False
# 4                40        4716.0                             False
# ...             ...           ...                               ...
# 10122            50        4003.0                             False
# 10123            41        4277.0                              True
# 10124            44        5409.0                              True
# 10125            30        5281.0                              True
# 10126            43       10388.0                              True
#
#        Attrition_Flag_Existing Customer  Gender_F  Gender_M
# 0                                  True     False      True
# 1                                  True      True     False
# 2                                  True     False      True
# 3                                  True      True     False
# 4                                  True     False      True
# ...                                 ...       ...       ...
# 10122                              True     False      True
# 10123                             False     False      True
# 10124                             False      True     False
# 10125                             False     False      True
# 10126                             False      True     False
#
# [10127 rows x 6 columns]

# %%
churn = pd.get_dummies(churn)

churn.head()
# Out:
#    Customer_Age  Credit_Limit  Attrition_Flag_Attrited Customer  \
# 0            45       12691.0                             False
# 1            49        8256.0                             False
# 2            51        3418.0                             False
# 3            40        3313.0                             False
# 4            40        4716.0                             False
#
#    Attrition_Flag_Existing Customer  Gender_F  Gender_M
# 0                              True     False      True
# 1                              True      True     False
# 2                              True     False      True
# 3                              True      True     False
# 4                              True     False      True

# %% [markdown]
# ## Exercise 8 - get_dummies function

# %%
churn = pd.read_csv(
    
    "Data/BankChurners.csv",
    usecols=["Customer_Age", "Attrition_Flag", "Gender", "Credit_Limit"]

)

churn.head()
# Out:
#       Attrition_Flag  Customer_Age Gender  Credit_Limit
# 0  Existing Customer            45      M       12691.0
# 1  Existing Customer            49      F        8256.0
# 2  Existing Customer            51      M        3418.0
# 3  Existing Customer            40      F        3313.0
# 4  Existing Customer            40      M        4716.0

# %%
churn = pd.get_dummies(churn, drop_first=True)

churn.head()
# Out:
#    Customer_Age  Credit_Limit  Attrition_Flag_Existing Customer  Gender_M
# 0            45       12691.0                              True      True
# 1            49        8256.0                              True     False
# 2            51        3418.0                              True      True
# 3            40        3313.0                              True     False
# 4            40        4716.0                              True      True

# %% [markdown]
# ## Exercise 9 - from_dummies function
#
# * New in version 1.5.0.

# %%
churn = pd.read_csv(
    
    "Data/BankChurners.csv",
    usecols=["Customer_Age", "Attrition_Flag", "Gender", "Credit_Limit"]

)

churn = pd.get_dummies(churn)

churn.head()
# Out:
#    Customer_Age  Credit_Limit  Attrition_Flag_Attrited Customer  \
# 0            45       12691.0                             False
# 1            49        8256.0                             False
# 2            51        3418.0                             False
# 3            40        3313.0                             False
# 4            40        4716.0                             False
#
#    Attrition_Flag_Existing Customer  Gender_F  Gender_M
# 0                              True     False      True
# 1                              True      True     False
# 2                              True     False      True
# 3                              True      True     False
# 4                              True     False      True

# %%
pd.from_dummies(churn[["Gender_F", "Gender_M"]])
# Out:
#
# 0      Gender_M
# 1      Gender_F
# 2      Gender_M
# 3      Gender_F
# 4      Gender_M
# ...         ...
# 10122  Gender_M
# 10123  Gender_M
# 10124  Gender_F
# 10125  Gender_M
# 10126  Gender_F
#
# [10127 rows x 1 columns]

# %%
churn["Gender"] = pd.from_dummies(churn[["Gender_F", "Gender_M"]])

churn.head()
# Out:
#    Customer_Age  Credit_Limit  Attrition_Flag_Attrited Customer  \
# 0            45       12691.0                             False
# 1            49        8256.0                             False
# 2            51        3418.0                             False
# 3            40        3313.0                             False
# 4            40        4716.0                             False
#
#    Attrition_Flag_Existing Customer  Gender_F  Gender_M    Gender
# 0                              True     False      True  Gender_M
# 1                              True      True     False  Gender_F
# 2                              True     False      True  Gender_M
# 3                              True      True     False  Gender_F
# 4                              True     False      True  Gender_M

# %% [markdown]
# ## Exercise 10 - add_prefix and add_suffix

# %%
df = pd.DataFrame(np.random.randint(0, 10, size=(5, 3)), columns=list("ABC"))

df
# Out:
#    A  B  C
# 0  6  8  0
# 1  4  4  2
# 2  3  7  5
# 3  9  6  9
# 4  7  7  1

# %%
df.add_prefix("col_")
# Out:
#    col_A  col_B  col_C
# 0      6      8      0
# 1      4      4      2
# 2      3      7      5
# 3      9      6      9
# 4      7      7      1

# %%
df.add_suffix("_new")
# Out:
#    A_new  B_new  C_new
# 0      6      8      0
# 1      4      4      2
# 2      3      7      5
# 3      9      6      9
# 4      7      7      1
