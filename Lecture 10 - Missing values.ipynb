# %% [markdown]
# # Handling Missing Values
#
# * Real-life data comes with missing values
# * Do not ignore them
# * Proper ways to handle missing values

# %%
import numpy as np
import pandas as pd

df = pd.DataFrame(np.random.randint(10, size=(8,6)), columns=list("ABCDEF"))

df.iloc[[1,4],[0,3]] = np.nan
df.iloc[[3,7],[1,2,4]] = None

df
# Out:
#      A    B    C    D    E  F
# 0  7.0  5.0  9.0  8.0  2.0  2
# 1  NaN  2.0  7.0  NaN  1.0  9
# 2  4.0  4.0  7.0  2.0  1.0  0
# 3  6.0  NaN  NaN  0.0  NaN  8
# 4  NaN  8.0  9.0  NaN  9.0  7
# 5  0.0  1.0  9.0  0.0  8.0  4
# 6  7.0  5.0  4.0  7.0  3.0  3
# 7  3.0  NaN  NaN  9.0  NaN  7

# %%
df.dtypes
# Out:
# A    float64
# B    float64
# C    float64
# D    float64
# E    float64
# F      int64
# dtype: object

# %% [markdown]
# * A new missing data type (<NA>) introduced with Pandas 1.0 which is an integer type missing value representation.

# %%
df = pd.DataFrame(
    np.random.randint(10, size=(8, 6)), 
    columns=list("ABCDEF"),
    dtype=pd.Int64Dtype()
)

df.iloc[[1,4],[0,3]] = np.nan
df.iloc[[3,7],[1,2,4]] = None

df
# Out:
#       A     B     C     D     E  F
# 0     9     2     0     7     0  9
# 1  <NA>     1     4  <NA>     6  1
# 2     4     5     3     9     4  7
# 3     9  <NA>  <NA>     9  <NA>  2
# 4  <NA>     7     0  <NA>     0  2
# 5     5     9     6     5     0  4
# 6     9     3     7     7     7  1
# 7     3  <NA>  <NA>     8  <NA>  9

# %%
df.dtypes
# Out:
# A    Int64
# B    Int64
# C    Int64
# D    Int64
# E    Int64
# F    Int64
# dtype: object

# %% [markdown]
# ## 1. Finding missing values - isna

# %%
df
# Out:
#       A     B     C     D     E  F
# 0     9     2     0     7     0  9
# 1  <NA>     1     4  <NA>     6  1
# 2     4     5     3     9     4  7
# 3     9  <NA>  <NA>     9  <NA>  2
# 4  <NA>     7     0  <NA>     0  2
# 5     5     9     6     5     0  4
# 6     9     3     7     7     7  1
# 7     3  <NA>  <NA>     8  <NA>  9

# %%
df.isna()
# Out:
#        A      B      C      D      E      F
# 0  False  False  False  False  False  False
# 1   True  False  False   True  False  False
# 2  False  False  False  False  False  False
# 3  False   True   True  False   True  False
# 4   True  False  False   True  False  False
# 5  False  False  False  False  False  False
# 6  False  False  False  False  False  False
# 7  False   True   True  False   True  False

# %% [markdown]
# ## 2. Finding missing values - isnull

# %%
df.isnull()
# Out:
#        A      B      C      D      E      F
# 0  False  False  False  False  False  False
# 1   True  False  False   True  False  False
# 2  False  False  False  False  False  False
# 3  False   True   True  False   True  False
# 4   True  False  False   True  False  False
# 5  False  False  False  False  False  False
# 6  False  False  False  False  False  False
# 7  False   True   True  False   True  False

# %% [markdown]
# ## 3. Finding missing values - notna

# %%
df.notna()
# Out:
#        A      B      C      D      E     F
# 0   True   True   True   True   True  True
# 1  False   True   True  False   True  True
# 2   True   True   True   True   True  True
# 3   True  False  False   True  False  True
# 4  False   True   True  False   True  True
# 5   True   True   True   True   True  True
# 6   True   True   True   True   True  True
# 7   True  False  False   True  False  True

# %% [markdown]
# ## 4. Number of missing values - column

# %%
df
# Out:
#       A     B     C     D     E  F
# 0     9     2     0     7     0  9
# 1  <NA>     1     4  <NA>     6  1
# 2     4     5     3     9     4  7
# 3     9  <NA>  <NA>     9  <NA>  2
# 4  <NA>     7     0  <NA>     0  2
# 5     5     9     6     5     0  4
# 6     9     3     7     7     7  1
# 7     3  <NA>  <NA>     8  <NA>  9

# %%
df.isna().sum()
# Out:
# A    2
# B    2
# C    2
# D    2
# E    2
# F    0
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# 10

# %% [markdown]
# ## 5. Number of missing values - row

# %%
df
# Out:
#       A     B     C     D     E  F
# 0     9     2     0     7     0  9
# 1  <NA>     1     4  <NA>     6  1
# 2     4     5     3     9     4  7
# 3     9  <NA>  <NA>     9  <NA>  2
# 4  <NA>     7     0  <NA>     0  2
# 5     5     9     6     5     0  4
# 6     9     3     7     7     7  1
# 7     3  <NA>  <NA>     8  <NA>  9

# %%
df.isna().sum(axis=1)
# Out:
# 0    0
# 1    2
# 2    0
# 3    3
# 4    2
# 5    0
# 6    0
# 7    3
# dtype: int64

# %% [markdown]
# ## 6. Dropping missing values

# %%
df
# Out:
#       A     B     C     D     E  F
# 0     9     2     0     7     0  9
# 1  <NA>     1     4  <NA>     6  1
# 2     4     5     3     9     4  7
# 3     9  <NA>  <NA>     9  <NA>  2
# 4  <NA>     7     0  <NA>     0  2
# 5     5     9     6     5     0  4
# 6     9     3     7     7     7  1
# 7     3  <NA>  <NA>     8  <NA>  9

# %%
df.dropna()
# Out:
#    A  B  C  D  E  F
# 0  9  2  0  7  0  9
# 2  4  5  3  9  4  7
# 5  5  9  6  5  0  4
# 6  9  3  7  7  7  1

# %% [markdown]
# ## 7. Dropping missing values - axis parameter

# %%
df.dropna(axis=1)
# Out:
#    F
# 0  9
# 1  1
# 2  7
# 3  2
# 4  2
# 5  4
# 6  1
# 7  9

# %% [markdown]
# ## 8. Dropping missing values - how parameter

# %%
df
# Out:
#       A     B     C     D     E  F
# 0     9     2     0     7     0  9
# 1  <NA>     1     4  <NA>     6  1
# 2     4     5     3     9     4  7
# 3     9  <NA>  <NA>     9  <NA>  2
# 4  <NA>     7     0  <NA>     0  2
# 5     5     9     6     5     0  4
# 6     9     3     7     7     7  1
# 7     3  <NA>  <NA>     8  <NA>  9

# %%
df.dropna(how="any")
# Out:
#    A  B  C  D  E  F
# 0  9  2  0  7  0  9
# 2  4  5  3  9  4  7
# 5  5  9  6  5  0  4
# 6  9  3  7  7  7  1

# %%
df.dropna(how="all")
# Out:
#       A     B     C     D     E  F
# 0     9     2     0     7     0  9
# 1  <NA>     1     4  <NA>     6  1
# 2     4     5     3     9     4  7
# 3     9  <NA>  <NA>     9  <NA>  2
# 4  <NA>     7     0  <NA>     0  2
# 5     5     9     6     5     0  4
# 6     9     3     7     7     7  1
# 7     3  <NA>  <NA>     8  <NA>  9

# %%
df.dropna(how="any", axis=1)
# Out:
#    F
# 0  9
# 1  1
# 2  7
# 3  2
# 4  2
# 5  4
# 6  1
# 7  9

# %%
df.dropna(how="all", axis=1)
# Out:
#       A     B     C     D     E  F
# 0     9     2     0     7     0  9
# 1  <NA>     1     4  <NA>     6  1
# 2     4     5     3     9     4  7
# 3     9  <NA>  <NA>     9  <NA>  2
# 4  <NA>     7     0  <NA>     0  2
# 5     5     9     6     5     0  4
# 6     9     3     7     7     7  1
# 7     3  <NA>  <NA>     8  <NA>  9

# %% [markdown]
# ## 9. Dropping missing values - thresh parameter
#
# * We can set a threshold based on the number of non-missing values in order for a row/column to be dropped.
#
# * The thresh parameter requires a row or column to have at least the specified number of non-missing values not to be dropped.
#
# * Cannot be combined with the how parameter

# %%
df
# Out:
#       A     B     C     D     E  F
# 0     9     2     0     7     0  9
# 1  <NA>     1     4  <NA>     6  1
# 2     4     5     3     9     4  7
# 3     9  <NA>  <NA>     9  <NA>  2
# 4  <NA>     7     0  <NA>     0  2
# 5     5     9     6     5     0  4
# 6     9     3     7     7     7  1
# 7     3  <NA>  <NA>     8  <NA>  9

# %%
df.dropna(thresh=4)
# Out:
#       A  B  C     D  E  F
# 0     9  2  0     7  0  9
# 1  <NA>  1  4  <NA>  6  1
# 2     4  5  3     9  4  7
# 4  <NA>  7  0  <NA>  0  2
# 5     5  9  6     5  0  4
# 6     9  3  7     7  7  1

# %%
df.dropna(thresh=2)
# Out:
#       A     B     C     D     E  F
# 0     9     2     0     7     0  9
# 1  <NA>     1     4  <NA>     6  1
# 2     4     5     3     9     4  7
# 3     9  <NA>  <NA>     9  <NA>  2
# 4  <NA>     7     0  <NA>     0  2
# 5     5     9     6     5     0  4
# 6     9     3     7     7     7  1
# 7     3  <NA>  <NA>     8  <NA>  9

# %% [markdown]
# ## 10. Dropping missing values - thresh parameter - columns

# %%
df.dropna(thresh=6, axis=1)
# Out:
#       A     B     C     D     E  F
# 0     9     2     0     7     0  9
# 1  <NA>     1     4  <NA>     6  1
# 2     4     5     3     9     4  7
# 3     9  <NA>  <NA>     9  <NA>  2
# 4  <NA>     7     0  <NA>     0  2
# 5     5     9     6     5     0  4
# 6     9     3     7     7     7  1
# 7     3  <NA>  <NA>     8  <NA>  9

# %%
df.iloc[0, 0] = np.nan

df
# Out:
#       A     B     C     D     E  F
# 0  <NA>     2     0     7     0  9
# 1  <NA>     1     4  <NA>     6  1
# 2     4     5     3     9     4  7
# 3     9  <NA>  <NA>     9  <NA>  2
# 4  <NA>     7     0  <NA>     0  2
# 5     5     9     6     5     0  4
# 6     9     3     7     7     7  1
# 7     3  <NA>  <NA>     8  <NA>  9

# %%
df.dropna(thresh=6, axis=1)
# Out:
#       B     C     D     E  F
# 0     2     0     7     0  9
# 1     1     4  <NA>     6  1
# 2     5     3     9     4  7
# 3  <NA>  <NA>     9  <NA>  2
# 4     7     0  <NA>     0  2
# 5     9     6     5     0  4
# 6     3     7     7     7  1
# 7  <NA>  <NA>     8  <NA>  9

# %% [markdown]
# ## 11. Dropping missing values - inplace

# %%
df.dropna(thresh=4)
# Out:
#       A  B  C     D  E  F
# 0  <NA>  2  0     7  0  9
# 1  <NA>  1  4  <NA>  6  1
# 2     4  5  3     9  4  7
# 4  <NA>  7  0  <NA>  0  2
# 5     5  9  6     5  0  4
# 6     9  3  7     7  7  1

# %%
df
# Out:
#       A     B     C     D     E  F
# 0  <NA>     2     0     7     0  9
# 1  <NA>     1     4  <NA>     6  1
# 2     4     5     3     9     4  7
# 3     9  <NA>  <NA>     9  <NA>  2
# 4  <NA>     7     0  <NA>     0  2
# 5     5     9     6     5     0  4
# 6     9     3     7     7     7  1
# 7     3  <NA>  <NA>     8  <NA>  9

# %%
df.dropna(thresh=4, inplace=True)

# %%
df
# Out:
#       A  B  C     D  E  F
# 0  <NA>  2  0     7  0  9
# 1  <NA>  1  4  <NA>  6  1
# 2     4  5  3     9  4  7
# 4  <NA>  7  0  <NA>  0  2
# 5     5  9  6     5  0  4
# 6     9  3  7     7  7  1

# %% [markdown]
# ## 12. Dropping missing values - assign to the same variable

# %%
df = pd.DataFrame(
    np.random.randint(10, size=(8, 6)), 
    columns=list("ABCDEF")
)

df.iloc[[1,4],[0,3]] = np.nan
df.iloc[[3,7],[1,2,4]] = None

df
# Out:
#      A    B    C    D    E  F
# 0  6.0  2.0  6.0  3.0  3.0  2
# 1  NaN  2.0  4.0  NaN  1.0  1
# 2  3.0  0.0  3.0  6.0  1.0  8
# 3  1.0  NaN  NaN  4.0  NaN  4
# 4  NaN  0.0  1.0  NaN  4.0  8
# 5  1.0  8.0  4.0  7.0  1.0  8
# 6  5.0  8.0  6.0  7.0  0.0  3
# 7  4.0  NaN  NaN  1.0  NaN  4

# %%
df = df.dropna(thresh=4)

# %%
df
# Out:
#      A    B    C    D    E  F
# 0  6.0  2.0  6.0  3.0  3.0  2
# 1  NaN  2.0  4.0  NaN  1.0  1
# 2  3.0  0.0  3.0  6.0  1.0  8
# 4  NaN  0.0  1.0  NaN  4.0  8
# 5  1.0  8.0  4.0  7.0  1.0  8
# 6  5.0  8.0  6.0  7.0  0.0  3

# %% [markdown]
# ## 13. Dropping missing values - subset parameter

# %%
df = pd.DataFrame(
    np.random.randint(10, size=(8, 6)), 
    columns=list("ABCDEF")
)

df.iloc[[1,4],[0]] = np.nan
df.iloc[[4,5],[1]] = np.nan
df.iloc[[3,6],[2]] = np.nan
df.iloc[[1,7],[3]] = np.nan

df
# Out:
#      A    B    C    D  E  F
# 0  5.0  4.0  8.0  5.0  5  7
# 1  NaN  1.0  3.0  NaN  4  9
# 2  5.0  7.0  7.0  3.0  0  0
# 3  9.0  4.0  NaN  4.0  5  1
# 4  NaN  NaN  5.0  0.0  8  9
# 5  0.0  NaN  4.0  7.0  6  3
# 6  9.0  2.0  NaN  8.0  2  4
# 7  6.0  5.0  5.0  NaN  8  8

# %%
df.dropna(subset=["A", "B"])
# Out:
#      A    B    C    D  E  F
# 0  5.0  4.0  8.0  5.0  5  7
# 2  5.0  7.0  7.0  3.0  0  0
# 3  9.0  4.0  NaN  4.0  5  1
# 6  9.0  2.0  NaN  8.0  2  4
# 7  6.0  5.0  5.0  NaN  8  8

# %%
df.dropna(subset=["A"])
# Out:
#      A    B    C    D  E  F
# 0  5.0  4.0  8.0  5.0  5  7
# 2  5.0  7.0  7.0  3.0  0  0
# 3  9.0  4.0  NaN  4.0  5  1
# 5  0.0  NaN  4.0  7.0  6  3
# 6  9.0  2.0  NaN  8.0  2  4
# 7  6.0  5.0  5.0  NaN  8  8

# %% [markdown]
# ## 14. Dropping missing values - subset and thresh

# %%
df
# Out:
#      A    B    C    D  E  F
# 0  5.0  4.0  8.0  5.0  5  7
# 1  NaN  1.0  3.0  NaN  4  9
# 2  5.0  7.0  7.0  3.0  0  0
# 3  9.0  4.0  NaN  4.0  5  1
# 4  NaN  NaN  5.0  0.0  8  9
# 5  0.0  NaN  4.0  7.0  6  3
# 6  9.0  2.0  NaN  8.0  2  4
# 7  6.0  5.0  5.0  NaN  8  8

# %%
df.dropna(subset=["A", "B"], thresh=1)
# Out:
#      A    B    C    D  E  F
# 0  5.0  4.0  8.0  5.0  5  7
# 1  NaN  1.0  3.0  NaN  4  9
# 2  5.0  7.0  7.0  3.0  0  0
# 3  9.0  4.0  NaN  4.0  5  1
# 5  0.0  NaN  4.0  7.0  6  3
# 6  9.0  2.0  NaN  8.0  2  4
# 7  6.0  5.0  5.0  NaN  8  8

# %% [markdown]
# ## 15. Filling missing values - constant

# %%
df
# Out:
#      A    B    C    D  E  F
# 0  5.0  4.0  8.0  5.0  5  7
# 1  NaN  1.0  3.0  NaN  4  9
# 2  5.0  7.0  7.0  3.0  0  0
# 3  9.0  4.0  NaN  4.0  5  1
# 4  NaN  NaN  5.0  0.0  8  9
# 5  0.0  NaN  4.0  7.0  6  3
# 6  9.0  2.0  NaN  8.0  2  4
# 7  6.0  5.0  5.0  NaN  8  8

# %%
df.fillna(value=0)
# Out:
#      A    B    C    D  E  F
# 0  5.0  4.0  8.0  5.0  5  7
# 1  0.0  1.0  3.0  0.0  4  9
# 2  5.0  7.0  7.0  3.0  0  0
# 3  9.0  4.0  0.0  4.0  5  1
# 4  0.0  0.0  5.0  0.0  8  9
# 5  0.0  0.0  4.0  7.0  6  3
# 6  9.0  2.0  0.0  8.0  2  4
# 7  6.0  5.0  5.0  0.0  8  8

# %% [markdown]
# ## 16. Filling missing values - constant - 2

# %%
df.fillna(value={"A": 0, "B": 10})
# Out:
#      A     B    C    D  E  F
# 0  5.0   4.0  8.0  5.0  5  7
# 1  0.0   1.0  3.0  NaN  4  9
# 2  5.0   7.0  7.0  3.0  0  0
# 3  9.0   4.0  NaN  4.0  5  1
# 4  0.0  10.0  5.0  0.0  8  9
# 5  0.0  10.0  4.0  7.0  6  3
# 6  9.0   2.0  NaN  8.0  2  4
# 7  6.0   5.0  5.0  NaN  8  8

# %% [markdown]
# ## 17. Filling missing values - basic statistics

# %%
df
# Out:
#      A    B    C    D  E  F
# 0  5.0  4.0  8.0  5.0  5  7
# 1  NaN  1.0  3.0  NaN  4  9
# 2  5.0  7.0  7.0  3.0  0  0
# 3  9.0  4.0  NaN  4.0  5  1
# 4  NaN  NaN  5.0  0.0  8  9
# 5  0.0  NaN  4.0  7.0  6  3
# 6  9.0  2.0  NaN  8.0  2  4
# 7  6.0  5.0  5.0  NaN  8  8

# %%
df["A"] = df["A"].fillna(value=df["A"].mean())

df
# Out:
#           A    B    C    D  E  F
# 0  5.000000  4.0  8.0  5.0  5  7
# 1  5.666667  1.0  3.0  NaN  4  9
# 2  5.000000  7.0  7.0  3.0  0  0
# 3  9.000000  4.0  NaN  4.0  5  1
# 4  5.666667  NaN  5.0  0.0  8  9
# 5  0.000000  NaN  4.0  7.0  6  3
# 6  9.000000  2.0  NaN  8.0  2  4
# 7  6.000000  5.0  5.0  NaN  8  8

# %%
df["B"] = df["B"].fillna(value=df["B"].min())

df
# Out:
#           A    B    C    D  E  F
# 0  5.000000  4.0  8.0  5.0  5  7
# 1  5.666667  1.0  3.0  NaN  4  9
# 2  5.000000  7.0  7.0  3.0  0  0
# 3  9.000000  4.0  NaN  4.0  5  1
# 4  5.666667  1.0  5.0  0.0  8  9
# 5  0.000000  1.0  4.0  7.0  6  3
# 6  9.000000  2.0  NaN  8.0  2  4
# 7  6.000000  5.0  5.0  NaN  8  8

# %% [markdown]
# ## 18. Filling missing values - with another DataFrame

# %%
df1 = pd.DataFrame(np.random.randint(1, 10, size=(4, 5)))
df1.iloc[[0, 2], [1, 3]] = np.nan

df1
# Out:
#    0    1  2    3  4
# 0  7  NaN  1  NaN  3
# 1  4  4.0  2  4.0  7
# 2  3  NaN  2  NaN  9
# 3  4  1.0  1  5.0  2

# %%
df2 = pd.DataFrame(np.random.randint(1, 10, size=(4, 5)))

df2
# Out:
#    0  1  2  3  4
# 0  3  5  2  1  9
# 1  9  9  5  3  8
# 2  5  6  3  8  8
# 3  8  2  3  9  2

# %%
df1 = df1.fillna(df2)

df1
# Out:
#    0    1  2    3  4
# 0  7  5.0  1  1.0  3
# 1  4  4.0  2  4.0  7
# 2  3  6.0  2  8.0  9
# 3  4  1.0  1  5.0  2

# %% [markdown]
# ## 19. Filling missing values - method parameter

# %%
df = pd.DataFrame(
    np.random.randint(1, 50, size=(10, 5)),
    columns=["col1", "col2", "col3", "col4", "col5"],
    index=pd.date_range(start="2022-12-05", periods=10, freq="D")
)

df.iloc[[3, 4], [0, 1]] = np.nan
df.iloc[[5], [0]] = np.nan
df.iloc[[5, 6], [2]] = np.nan

df
# Out:
#             col1  col2  col3  col4  col5
# 2022-12-05  42.0   3.0   3.0    49    24
# 2022-12-06  11.0  37.0  35.0    27    36
# 2022-12-07  22.0   5.0  15.0    24    30
# 2022-12-08   NaN   NaN  48.0    25    16
# 2022-12-09   NaN   NaN  22.0    18    35
# 2022-12-10   NaN  41.0   NaN    31     9
# 2022-12-11  21.0  39.0   NaN    14    26
# 2022-12-12  48.0  32.0   4.0    44    35
# 2022-12-13   1.0  20.0  39.0     9     5
# 2022-12-14  33.0  32.0  20.0     4    37

# %%
df.fillna(method="ffill")
# Out:
#             col1  col2  col3  col4  col5
# 2022-12-05  42.0   3.0   3.0    49    24
# 2022-12-06  11.0  37.0  35.0    27    36
# 2022-12-07  22.0   5.0  15.0    24    30
# 2022-12-08  22.0   5.0  48.0    25    16
# 2022-12-09  22.0   5.0  22.0    18    35
# 2022-12-10  22.0  41.0  22.0    31     9
# 2022-12-11  21.0  39.0  22.0    14    26
# 2022-12-12  48.0  32.0   4.0    44    35
# 2022-12-13   1.0  20.0  39.0     9     5
# 2022-12-14  33.0  32.0  20.0     4    37

# %% [markdown]
# ## 20. Filling missing values - method parameter 2

# %%
df["col3"] = df["col3"].fillna(method="ffill")

df
# Out:
#             col1  col2  col3  col4  col5
# 2022-12-05  42.0   3.0   3.0    49    24
# 2022-12-06  11.0  37.0  35.0    27    36
# 2022-12-07  22.0   5.0  15.0    24    30
# 2022-12-08   NaN   NaN  48.0    25    16
# 2022-12-09   NaN   NaN  22.0    18    35
# 2022-12-10   NaN  41.0  22.0    31     9
# 2022-12-11  21.0  39.0  22.0    14    26
# 2022-12-12  48.0  32.0   4.0    44    35
# 2022-12-13   1.0  20.0  39.0     9     5
# 2022-12-14  33.0  32.0  20.0     4    37

# %% [markdown]
# ## 21. Filling missing values - method parameter 3

# %%
df
# Out:
#             col1  col2  col3  col4  col5
# 2022-12-05  42.0   3.0   3.0    49    24
# 2022-12-06  11.0  37.0  35.0    27    36
# 2022-12-07  22.0   5.0  15.0    24    30
# 2022-12-08   NaN   NaN  48.0    25    16
# 2022-12-09   NaN   NaN  22.0    18    35
# 2022-12-10   NaN  41.0  22.0    31     9
# 2022-12-11  21.0  39.0  22.0    14    26
# 2022-12-12  48.0  32.0   4.0    44    35
# 2022-12-13   1.0  20.0  39.0     9     5
# 2022-12-14  33.0  32.0  20.0     4    37

# %%
df.fillna(method="bfill")
# Out:
#             col1  col2  col3  col4  col5
# 2022-12-05  42.0   3.0   3.0    49    24
# 2022-12-06  11.0  37.0  35.0    27    36
# 2022-12-07  22.0   5.0  15.0    24    30
# 2022-12-08  21.0  41.0  48.0    25    16
# 2022-12-09  21.0  41.0  22.0    18    35
# 2022-12-10  21.0  41.0  22.0    31     9
# 2022-12-11  21.0  39.0  22.0    14    26
# 2022-12-12  48.0  32.0   4.0    44    35
# 2022-12-13   1.0  20.0  39.0     9     5
# 2022-12-14  33.0  32.0  20.0     4    37

# %% [markdown]
# ## 22. Filling missing values - method and limit

# %%
df
# Out:
#             col1  col2  col3  col4  col5
# 2022-12-05  42.0   3.0   3.0    49    24
# 2022-12-06  11.0  37.0  35.0    27    36
# 2022-12-07  22.0   5.0  15.0    24    30
# 2022-12-08   NaN   NaN  48.0    25    16
# 2022-12-09   NaN   NaN  22.0    18    35
# 2022-12-10   NaN  41.0  22.0    31     9
# 2022-12-11  21.0  39.0  22.0    14    26
# 2022-12-12  48.0  32.0   4.0    44    35
# 2022-12-13   1.0  20.0  39.0     9     5
# 2022-12-14  33.0  32.0  20.0     4    37

# %%
df.fillna(method="ffill", limit=2)
# Out:
#             col1  col2  col3  col4  col5
# 2022-12-05  42.0   3.0   3.0    49    24
# 2022-12-06  11.0  37.0  35.0    27    36
# 2022-12-07  22.0   5.0  15.0    24    30
# 2022-12-08  22.0   5.0  48.0    25    16
# 2022-12-09  22.0   5.0  22.0    18    35
# 2022-12-10   NaN  41.0  22.0    31     9
# 2022-12-11  21.0  39.0  22.0    14    26
# 2022-12-12  48.0  32.0   4.0    44    35
# 2022-12-13   1.0  20.0  39.0     9     5
# 2022-12-14  33.0  32.0  20.0     4    37

# %% [markdown]
# ## 23. The ffill function

# %%
df
# Out:
#             col1  col2  col3  col4  col5
# 2022-12-05  42.0   3.0   3.0    49    24
# 2022-12-06  11.0  37.0  35.0    27    36
# 2022-12-07  22.0   5.0  15.0    24    30
# 2022-12-08   NaN   NaN  48.0    25    16
# 2022-12-09   NaN   NaN  22.0    18    35
# 2022-12-10   NaN  41.0  22.0    31     9
# 2022-12-11  21.0  39.0  22.0    14    26
# 2022-12-12  48.0  32.0   4.0    44    35
# 2022-12-13   1.0  20.0  39.0     9     5
# 2022-12-14  33.0  32.0  20.0     4    37

# %%
df.ffill(limit=2)
# Out:
#             col1  col2  col3  col4  col5
# 2022-12-05  42.0   3.0   3.0    49    24
# 2022-12-06  11.0  37.0  35.0    27    36
# 2022-12-07  22.0   5.0  15.0    24    30
# 2022-12-08  22.0   5.0  48.0    25    16
# 2022-12-09  22.0   5.0  22.0    18    35
# 2022-12-10   NaN  41.0  22.0    31     9
# 2022-12-11  21.0  39.0  22.0    14    26
# 2022-12-12  48.0  32.0   4.0    44    35
# 2022-12-13   1.0  20.0  39.0     9     5
# 2022-12-14  33.0  32.0  20.0     4    37

# %% [markdown]
# ## 24. The bfill function

# %%
df.bfill(limit=2)
# Out:
#             col1  col2  col3  col4  col5
# 2022-12-05  42.0   3.0   3.0    49    24
# 2022-12-06  11.0  37.0  35.0    27    36
# 2022-12-07  22.0   5.0  15.0    24    30
# 2022-12-08   NaN  41.0  48.0    25    16
# 2022-12-09  21.0  41.0  22.0    18    35
# 2022-12-10  21.0  41.0  22.0    31     9
# 2022-12-11  21.0  39.0  22.0    14    26
# 2022-12-12  48.0  32.0   4.0    44    35
# 2022-12-13   1.0  20.0  39.0     9     5
# 2022-12-14  33.0  32.0  20.0     4    37

# %% [markdown]
# ## 25. na_values parameter of the read_csv function

# %%
df = pd.read_csv("Data/sample_dataset.csv")

df
# Out:
#    col1  col2 col3  col4  col5
# 0  23.0  16.0   45    17     2
# 1  46.0  16.0   24     2    31
# 2   2.0  29.0    2    46    24
# 3   NaN   NaN   25    23     7
# 4   NaN   NaN   30    34    29
# 5   NaN  30.0    ?     5     6
# 6  35.0  37.0    ?    26    39
# 7   9.0   5.0   35    11    41
# 8  13.0  39.0   25     5    39
# 9  40.0  15.0   32    47    24

# %%
df = pd.read_csv("Data/sample_dataset.csv", na_values=["?"])

df
# Out:
#    col1  col2  col3  col4  col5
# 0  23.0  16.0  45.0    17     2
# 1  46.0  16.0  24.0     2    31
# 2   2.0  29.0   2.0    46    24
# 3   NaN   NaN  25.0    23     7
# 4   NaN   NaN  30.0    34    29
# 5   NaN  30.0   NaN     5     6
# 6  35.0  37.0   NaN    26    39
# 7   9.0   5.0  35.0    11    41
# 8  13.0  39.0  25.0     5    39
# 9  40.0  15.0  32.0    47    24
